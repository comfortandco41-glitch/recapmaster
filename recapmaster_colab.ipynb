# %% [markdown]
# # 🎬 RecapMaster AI - Free Google Colab Runner
# Run RecapMaster 100% free with a free NVIDIA GPU on Google Colab!
#
# 1. Click the Play button on **Cell 1** to install dependencies.
# 2. Click the Play button on **Cell 2** to launch the web studio.
# 3. Open the generated **`https://xxxx.gradio.live`** public link in your browser!

# %%
# @title ⚡ 1. Install System & Python Dependencies
# !apt-get update -qq
# !apt-get install -y -qq ffmpeg libass-dev fonts-sil-padauk fonts-noto-core
# !git clone https://huggingface.co/spaces/Kan201/recapmaster
# %cd recapmaster
# !pip install -q -r requirements.txt

# %%
# @title 🚀 2. Start RecapMaster AI (Generates Free Public Link)
# %cd /content/recapmaster
# !python app.py
